# %%
import matplotlib.pyplot as plt
import numpy as np
import random
# %matplotlib inline
random.seed(123)

# %%
x = np.arange(-5, 5, 0.1)
k = random.randint(-2, 2) * random.random()
y1 = np.cos(x) # k = 1
y2 = np.cos(k * x)

# %%
plt.plot(x,y1, x,y2)
plt.show()
